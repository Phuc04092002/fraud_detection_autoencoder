# %%
#Kết nối với Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Truy cập file dữ liệu và unzip
# %cd /content/drive/MyDrive/Mi AI/Fraud_detection_autoencoder
# !unzip fraud_data.zip
# Out:
# /content/drive/MyDrive/Mi AI/Fraud_detection_autoencoder
# Archive:  fraud_data.zip
# replace creditcard.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: creditcard.csv

# %%
#Đọc dữ liệu
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Mi AI/Fraud_detection_autoencoder/creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
#đếm số dòng dữ liệu
df.count()
# Out:
# Time      284807
# V1        284807
# V2        284807
# V3        284807
# V4        284807
# V5        284807
# V6        284807
# V7        284807
# V8        284807
# V9        284807
# V10       284807
# V11       284807
# V12       284807
# V13       284807
# V14       284807
# V15       284807
# V16       284807
# V17       284807
# V18       284807
# V19       284807
# V20       284807
# V21       284807
# V22       284807
# V23       284807
# V24       284807
# V25       284807
# V26       284807
# V27       284807
# V28       284807
# Amount    284807
# Class     284807
# dtype: int64

# %%
# Số dòng dữ liệu mỗi class
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# # **Train model auto Encoder**

# %%
# Drop cột time (vì nó vô nghĩa)
df_no_time = df.drop(columns=['Time'])
df_no_time.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  0.207643  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  0.753074  ... -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# 0  0.128539 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.167170  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.327642 -0.139097 -0.055353 -0.059752  378.66      0
# 3  0.647376 -0.221929  0.062723  0.061458  123.50      0
# 4 -0.206010  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 30 columns]

# %%
# Chuẩn hóa dữ liệu amount về (-1)-1
from sklearn.preprocessing import StandardScaler
df_no_time ['Amount'] = StandardScaler().fit_transform(df_no_time ['Amount'].values.reshape(-1,1))

# %%
df_no_time.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  0.207643  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  0.753074  ... -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28    Amount  Class
# 0  0.128539 -0.189115  0.133558 -0.021053  0.244964      0
# 1  0.167170  0.125895 -0.008983  0.014724 -0.342475      0
# 2 -0.327642 -0.139097 -0.055353 -0.059752  1.160686      0
# 3  0.647376 -0.221929  0.062723  0.061458  0.140534      0
# 4 -0.206010  0.502292  0.219422  0.215153 -0.073403      0
#
# [5 rows x 30 columns]

# %%
# Phân chia dữ liệu train-test
from sklearn.model_selection import train_test_split
X_train, X_test = train_test_split(df_no_time, test_size=0.2, random_state=42)

# Điều chế dữ liệu train
X_train = X_train[X_train['Class'] == 0]
X_train = X_train.drop(columns=['Class'])

# Điều chế dữ liệu Test
Y_test = X_test['Class']
X_test = X_test.drop(columns=['Class'])

X_train=X_train.values
X_test=X_test.values

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (227451, 29)
# (56962, 29)

# %%
# Build Model
from keras.layers import Input, Dense
from keras.models import Model, load_model
from keras.callbacks import ModelCheckpoint

input_dimension = X_train.shape[1]
hidden_size = 128

input_layer = Input(shape=(input_dimension, ))

# Encoder
encoder = Dense(hidden_size, activation = 'relu' )(input_layer)
encoder = Dense(hidden_size//2, activation = 'relu' )(encoder)
encoder = Dense(hidden_size//4, activation ='relu')(encoder)

#Decoder
decoder = Dense(hidden_size//4, activation = 'relu')(encoder)
decoder = Dense(hidden_size//2, activation = 'relu')(decoder)
decoder = Dense(hidden_size, activation = 'relu')(decoder)

#Output
output_layer = Dense(input_dimension, activation='relu')(decoder)

auto_encoder_model = Model(inputs=input_layer, outputs=output_layer)
auto_encoder_model.compile(optimizer='adam', loss='mean_squared_error', metrics = ['accuracy'])
auto_encoder_model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 29)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │         3,840 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 29)             │         3,741 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 29,405 (114.86 KB)
#  Trainable params: 29,405 (114.86 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train model
n_epochs = 50
n_batch_size = 32

save_best = ModelCheckpoint(filepath = '/content/drive/MyDrive/Mi AI/Fraud_detection_autoencoder/best.h5', monitor = 'val_loss',verbose =1, save_best_only = True)

history = auto_encoder_model.fit(X_train, X_train, epochs = n_epochs, batch_size = n_batch_size,verbose=1, shuffle = True,
                                 validation_data =(X_test, X_test), callbacks = [save_best])
# Out:
# Epoch 1/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7150 - loss: 0.6827
# Epoch 1: val_loss improved from inf to 0.65803, saving model to /content/drive/MyDrive/Mi AI/Fraud_detection_autoencoder/best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 30s 4ms/step - accuracy: 0.7150 - loss: 0.6827 - val_accuracy: 0.8422 - val_loss: 0.6580
# Epoch 2/50
# 7087/7108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8457 - loss: 0.6107
# Epoch 2: val_loss improved from 0.65803 to 0.63156, saving model to /content/drive/MyDrive/Mi AI/Fraud_detection_autoencoder/best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 36s 3ms/step - accuracy: 0.8457 - loss: 0.6107 - val_accuracy: 0.8872 - val_loss: 0.6316
# Epoch 3/50
# 7094/7108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8769 - loss: 0.5965
# Epoch 3: val_loss did not improve from 0.63156
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 23s 3ms/step - accuracy: 0.8769 - loss: 0.5965 - val_accuracy: 0.8528 - val_loss: 0.6387
# Epoch 4/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8825 - loss: 0.5884
# Epoch 4: val_loss improved from 0.63156 to 0.62917, saving model to /content/drive/MyDrive/Mi AI/Fraud_detection_autoencoder/best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 44s 4ms/step - accuracy: 0.8825 - loss: 0.5884 - val_accuracy: 0.8896 - val_loss: 0.6292
# Epoch 5/50
# 7106/7108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8964 - loss: 0.5882
# Epoch 5: val_loss improved from 0.62917 to 0.62678, saving model to /content/drive/MyDrive/Mi AI/Fraud_detection_autoencoder/best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 39s 3ms/step - accuracy: 0.8964 - loss: 0.5882 - val_accuracy: 0.9007 - val_loss: 0.6268
# Epoch 6/50
# 7106/7108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9018 - loss: 0.5895
# Epoch 6: val_loss improved from 0.62678 to 0.62495, saving model to /content/drive/MyDrive/Mi AI/Fraud_detection_autoencoder/best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 40s 3ms/step - accuracy: 0.9018 - loss: 0.5895 - val_accuracy: 0.9101 - val_loss: 0.6249
# Epoch 7/50
# 7105/7108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9004 - loss: 0.6014
# Epoch 7: val_loss improved from 0.62495 to 0.62320, saving model to /content/drive/MyDrive/Mi AI/Fraud_detection_autoencoder/best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 24s 3ms/step - accuracy: 0.9004 - loss: 0.6014 - val_accuracy: 0.9139 - val_loss: 0.6232
# Epoch 8/50
# 7096/7108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9068 - loss: 0.5855
# Epoch 8: val_loss did not improve from 0.62320
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 42s 4ms/step - accuracy: 0.9068 - loss: 0.5855 - val_accuracy: 0.9099 - val_loss: 0.6243
# Epoch 9/50
# 7106/7108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9181 - loss: 0.5748
# Epoch 9: val_loss did not improve from 0.62320
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 23s 3ms/step - accuracy: 0.9181 - loss: 0.5748 - val_accuracy: 0.8935 - val_loss: 0.6270
# Epoch 10/50
# 7090/7108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9092 - loss: 0.5911
# Epoch 10: val_loss did not improve from 0.62320
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 23s 3ms/step - accuracy: 0.9092 - loss: 0.5911 - val_accuracy: 0.8950 - val_loss: 0.6252
# Epoch 11/50
# 7096/7108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9095 - loss: 0.5898
# Epoch 11: val_loss did not improve from 0.62320
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 41s 3ms/step - accuracy: 0.9095 - loss: 0.5898 - val_accuracy: 0.9163 - val_loss: 0.6237
# Epoch 12/50
# 7103/7108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9094 - loss: 0.5980
# Epoch 12: val_loss improved from 0.62320 to 0.62222, saving model to /content/drive/MyDrive/Mi AI/Fraud_detection_autoencoder/best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 43s 4ms/step - accuracy: 0.9094 - loss: 0.5980 - val_accuracy: 0.9327 - val_loss: 0.6222
# Epoch 13/50
# 7101/7108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9118 - loss: 0.5918
# Epoch 13: val_loss did not improve from 0.62222
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 23s 3ms/step - accuracy: 0.9118 - loss: 0.5918 - val_accuracy: 0.9327 - val_loss: 0.6321
# Epoch 14/50
# 2130/7108 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9272 - loss: 0.5735

# %%
# In History
import matplotlib.pyplot as plt
plt.plot(history.history ['loss'])
plt.plot(history.history ['val_loss'])
plt.legend()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %%
# Kiểm tra việc tái tạo trong tập test
import numpy as np

#Dự đoán
predicts = auto_encoder_model.predict(X_test)

mean_squared_error = np.mean(np.power(X_test - predicts,2), axis =1)

err_df = pd.DataFrame({'error': mean_squared_error, 'truth' : Y_test})

# %%
# In ra histogram của error khi tái tạo các điểm normal trong tập test
normal_error_df = err_df[(err_df['truth']==0) & (err_df['error']<10)]
_=plt.hist(normal_error_df.error.values, bins = 50)

# %%
# In ra histogram của error khi tái tạo các điểm fraud trong tập test
fraud_error_df = err_df[err_df['truth']==1]
_=plt.hist(fraud_error_df.error.values, bins = 50)

# %%
# Vẽ ra Confusion Matrix
from sklearn.metrics import confusion_matrix
import seaborn as sns

threshold = 2.3
y_pred= [1 if e> threshold else 0 for e in err_df['error'].values]
conf_matrix = confusion_matrix(err_df.truth, y_pred)

#Vẽ
sns.heatmap(conf_matrix, xticklabels = ["Normal", "Fraud"], yticklabels = ["Normal", "Fraud"], annot = True, fmt = 'd')
plt.title('Confusion Matrix')
plt.ylabel('Trust Values')
plt.xlabel('Predicted Values')
plt.show()
